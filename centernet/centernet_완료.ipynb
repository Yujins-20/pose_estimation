# %%
import cv2
import glob
import numpy as np
import os
from PIL import Image
#csv 앞,뒤 구분으로 다 합치기
# image 1000,1000 resize & 앞뒤합치기.. ctrl+s 생활화
img_name = os.listdir('/data3/chang/ypark/Centernet/data/resize/png_img/side/')
img = glob.glob("/data3/chang/ypark/Centernet/data/resize/png_img/side/*.jpg")
for i in range(len(img)):
    imgr = Image.open(img[i],'w')
    res = imgr.resize(imgr,dsize = (960,960),interpolation=cv2.INTER_CUBIC) # 1000으로 하면 oh
    res.save("/data3/chang/ypark/Centernet/data/resize/png_img/side/%s.jpg" %img_name[i])

# %%
import os
os.chdir('/content/drive/MyDrive/centernet-tf2-main-20220719T121658Z-001/centernet-tf2-main')

# %%
import glob
file = glob.glob('/content/drive/MyDrive/pose_estimation/data/split_frame/*_half.jpg')

# %%
import cv2
import glob
import matplotlib.pyplot as plt
import numpy as np
import os
#resize
import os
import glob
from PIL import Image

files = glob.glob('/data3/chang/ypark/Centernet/data/resize/png_img/side/*.png')
name = os.listdir('/data3/chang/ypark/Centernet/data/resize/png_img/side/')
#/content/drive/MyDrive/centernet-tf2-main-20220719T121658Z-001/data_512
for i,f in enumerate(files):
    img = Image.open(f)
    img_resize = img.resize((960, 960))
    title, ext = os.path.splitext(f)
    img_resize.save('/data3/chang/ypark/Centernet/data/resize/png_img/side_re/'+ name[i])

# %%
'''
import os 
import glob

list_im = glob.glob("/content/drive/MyDrive/pose_estimation/data/split_frame/*_half.jpg")
for i in list_im:
  os.remove(i)
  '''

# %%
error_num =[]
img_folder_path = "/content/drive/MyDrive/pose_estimation/data/split_frame/*_half.jpg"
img_path_list = glob.glob(img_folder_path)
joint_x_y = []
join = []
for i,path in enumerate(img_path_list):
    # green,yellow, red
    combi =  [(np.array([55,120,106]) ,np.array([77,235,240])),(np.array([11,199,180]) ,np.array([42,255,250])), (np.array([0,152,117]),np.array([5,200,170])), (np.array([169,153,102]),np.array([179,255,174]))]
#[(np.array([55,120,106]) ,np.array([77,235,240])),(np.array([11,199,180]) ,np.array([42,255,250])), (np.array([0,152,117]),np.array([5,200,170])), (np.array([169,153,102]),np.array([179,255,174]))]
    #[(np.array([29,119,125]) ,np.array([99,255,203])),(np.array([0,173,160]) ,np.array([61,255,249])), (np.array([0,142,116]),np.array([8,188,156])), (np.array([142,138,104]),np.array([179,250,187]))]
    img =cv2.imread(path)
    #img.resize = (1024,1024)
    #plt.figure(figsize=(30,30))
    #plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    #plt.show()
  
    try:
        coor_dict = labeling(img,combi)
        if coor_dict == 'gs':
            combi[0][0][0]=33
            #print('초록적')
        
        elif coor_dict == 'rl':
            combi[2] = (np.array([0, 120,148]),np.array([4, 220,190]))
            combi[3] = (np.array([167,177,115]),np.array([179,247,165]))
            #print('빨많')
        elif coor_dict == 'rs':
            combi[2] = (np.array([0,169,139]),np.array([15,203,207]))
            combi[3] = (np.array([170,136,137]),np.array([179,230,145]))
            #print('빨적')
        coor_dict = labeling(img,combi)
        if coor_dict =='gl':
            combi[0] = (np.array([31,137,71]),np.array([105,249,231]))
        elif coor_dict == 'rl':
            combi[2] = (np.array([0,135,144]),np.array([10,173,200]))
            combi[3] = (np.array([167,177,100]),np.array([179,247,165]))
            #print('빨많')
        if type(coor_dict)==str:
            print(coor_dict)
        coor_dict = labeling(img,combi)

        if type(coor_dict)==str:
            print(coor_dict)
        for point in coor_dict:
            
            coor = np.array(coor_dict[point])
            joint_x_y.append(coor_dict)
        join.append(i)
            #cv2.circle(img,coor,8,(255,255,255),-1)
            #cv2.circle(zero,coor,8,(255,255,255),-1)
            #cv2.putText(img,point,[coor[0]-30,coor[1]+30], cv2.FONT_HERSHEY_PLAIN,1.3,(28,28,28),2)
        cv2.imwrite(f"C:/Users/ypark/Downloads/split_frame-20220730T074057Z-001/result/b{i}.jpg",img)
        #cv2.imwrite(path.replace('split','marker'),zero)
        #plt.figure(figsize=(30,30))
        #plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        #plt.show()

    except:
        print(i,'이상')
        error_num.append(i)

# %% [markdown]
# 1080x1920
# -568 -1408

# %%
# !python /data3/chang/ypark/Centernet/centernet-tf2-main-20220719T121658Z-001/centernet-tf2-main/dataset/main.py
# Out:
#  >>> csv file has been loaded.
#
# ...
# [Log] Directory has been created.
# [Log] xml file has been created.
# [Log] Text file has been created.
# ...
#
#  >>> Done

# %%
# !python /data3/chang/ypark/Centernet/centernet-tf2-main-20220719T121658Z-001/centernet-tf2-main/dataset/xml_generate.py

# %%
# col/ voc_class,ceph_voc_class.text
# !python /data3/chang/ypark/Centernet/centernet-tf2-main-20220719T121658Z-001/centernet-tf2-main/voc_annotation.py
# Out:
# Generate txt in ImageSets.
# train and val size 1692
# train size 1522
# Generate txt in ImageSets done.
# Generate 2007_train.txt and 2007_val.txt for train.
# Generate 2007_train.txt and 2007_val.txt for train done.
# |     Knee | 1692 |
# |    Elbow | 1692 |
# |     Hand | 1692 |
# |    Ankle | 1692 |
# |     Neck | 1692 |
# | Shoulder | 1692 |
# |   Pelvis | 1692 |
# |     Side | 1692 |

# %%
#input_shape 36배수여야했네,batch_size너무 커도 오류
# !python /data3/chang/ypark/Centernet/centernet-tf2-main-20220719T121658Z-001/centernet-tf2-main/train.py
# Out:
# Number of devices: 1
# Load weights /data3/chang/ypark/Centernet/centernet-tf2-main-20220719T121658Z-001/centernet-tf2-main/logs/best_epoch_weights.h5.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |             classes_path | /data3/chang/ypark/Centernet/centernet-tf2-main-20220719T121658Z-001/centernet-tf2-main/model_data/voc_classes.txt|
# |               model_path | /data3/chang/ypark/Centernet/centernet-tf2-main-20220719T121658Z-001/centernet-tf2-main/logs/best_epoch_weights.h5|
# |              input_shape |                               [960, 960]|
# |               Init_Epoch |                                        0|
# |             Freeze_Epoch |                                      300|
# |           UnFreeze_Epoch |                                      500|
# ...

# %%
import cv2
import os
name = os.listdir('/data3/chang/ypark/Centernet/predict/test_data/')
for i in name:
    img = cv2.imread('/data3/chang/ypark/Centernet/predict/test_data/'+str(i), cv2.IMREAD_COLOR)
    img90 = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite('/data3/chang/ypark/Centernet/predict/test_datas/'+'90'+str(i), img90)

# %%
# !python /data3/chang/ypark/Centernet/centernet-tf2-main-20220719T121658Z-001/centernet-tf2-main/predict_ceph.py
# Out:
# 2023-03-16 21:24:04.748438: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-16 21:24:09.139418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11194 MB memory:  -> device: 0, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:05:00.0, compute capability: 6.1
# 2023-03-16 21:24:09.141294: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 11436 MB memory:  -> device: 1, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:06:00.0, compute capability: 6.1
# ...

# %%
#이미지 옮기기 dir
import shutil
for i in range(len(tjdwo)):
    filename = tjdwo[i].split('/')[-1]
    src = '/data3/chang/ypark/Centernet/data/resize/png_img/side_re/'
    dir = '/data3/chang/ypark/Centernet/predict/input/'
    shutil.move(src + filename, dir + filename)

# %%
import cv2
vidcap = cv2.VideoCapture('/data3/chang/ypark/Centernet/data/resize/WIN_20230302_19_18_25_Pro.mp4')
success,image = vidcap.read()
count = 0
while success:
  cv2.imwrite("/data3/chang/ypark/Centernet/predict/inputs/%06d.jpg" % count, image)     # save frame as JPEG file
  success,image = vidcap.read()
  print('Read a new frame: ', success)
  count += 1

print("finish! convert video to frame")

# %%
tjdwo[0].split('/')[-1].split('.')[0]
# Out:
# '150232_851862_mask_re.png'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2
import os

#pip install opencv-python

image_folder = '/content/drive/MyDrive/pose_estimation/data/split_frame/'
video_name = '/content/drive/MyDrive/label1.mp4'

#1. 모든 이미지 파일의 파일명을 리스트로 변환
images = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]
# print(images)

#2. 첫번째 이미지의 프레임크기 정보를 가져온다.
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape
# print(width, height, layers)

#3. 비디오 생성
# *은 'D', 'I', 'V', 'X' 이렇게 문자열을 문자로
video = cv2.VideoWriter(video_name, 
                        cv2.VideoWriter_fourcc(*'DIVX'), 
                        30, 
                        (width, height))

#4. 이미지 파일을 하나씩 가져와서 비디오에 추가
for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

#5. 종료
cv2.destroyAllWindows()
video.release()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-8f189ca6af08> in <module>
#      12
#      13 #2. 첫번째 이미지의 프레임크기 정보를 가져온다.
# ---> 14 frame = cv2.imread(os.path.join(image_folder, images[0]))
#      15 height, width, layers = frame.shape
#      16 # print(width, height, layers)
#
# IndexError: list index out of range

# %%
import cv2
import numpy as np
import os
import glob
import re
path = os.listdir("/content/drive/MyDrive/pose_estimation/imgouts/")
paths ='/content/drive/MyDrive/pose_estimation/imgouts'

#이미지에서 확장자명 제거
#path0 = [re.sub('.png', '', i) for i in path] 

#path0.remove('output1.mp4')
#path0.remove('output0.mp4')
#dd = sorted(path0, key=int)
#print(dd)

# %%
  # choose codec according to format needed
import glob
fourcc = cv2.VideoWriter_fourcc(*'DIVX') 
video = cv2.VideoWriter('/content/drive/MyDrive/label2.mp4', fourcc, 2, (512, 512), isColor=None)
imgs = glob.glob("/content/drive/MyDrive/pose_estimation/imgouts/*.png")
for j in range(len(path)):
   img = cv2.imread(imgs[j])
   video.write(img)
cv2.destroyAllWindows()
video.release()

# %%
import cv2
import glob
import numpy as np
img = glob.glob("/content/drive/MyDrive/split_test/*.jpg")
for i in range(len(img)):
    imgr = cv2.imread(img[i])
    res = cv2.resize(imgr,dsize = (512,512),interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("/content/drive/MyDrive/split_test/t%s.jpg" % i, res)

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture('/content/drive/MyDrive/data0.mp4')
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
# 추적 경로를 그리기 위한 랜덤 색상
color = np.random.randint(0,255,(200,3))
lines = None  #추적 선을 그릴 이미지 저장 변수
prevImg = None  # 이전 프레임 저장 변수
# calcOpticalFlowPyrLK 중지 요건 설정
termcriteria =  (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 10, 0.03)

while cap.isOpened():
    ret,frame = cap.read()
    if not ret:
        break
    img_draw = frame.copy()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # 최초 프레임 경우
    if prevImg is None:
        prevImg = gray
        # 추적선 그릴 이미지를 프레임 크기에 맞게 생성
        lines = np.zeros_like(frame)
        # 추적 시작을 위한 코너 검출  ---①
        prevPt = cv2.goodFeaturesToTrack(prevImg, 200, 0.01, 10)
    else:
        nextImg = gray
        # 옵티컬 플로우로 다음 프레임의 코너점  찾기 ---②
        nextPt, status, err = cv2.calcOpticalFlowPyrLK(prevImg, nextImg, \
                                        prevPt, None, criteria=termcriteria)
        # 대응점이 있는 코너, 움직인 코너 선별 ---③
        prevMv = prevPt[status==1]
        nextMv = nextPt[status==1]
        for i,(p, n) in enumerate(zip(prevMv, nextMv)):
            px,py = p.ravel()
            nx,ny = n.ravel()
            # 이전 코너와 새로운 코너에 선그리기 ---④
            cv2.line(lines, (px, py), (nx,ny), color[i].tolist(), 2)
            # 새로운 코너에 점 그리기
            cv2.circle(img_draw, (nx,ny), 2, color[i].tolist(), -1)
        # 누적된 추적 선을 출력 이미지에 합성 ---⑤
        img_draw = cv2.add(img_draw, lines)
        # 다음 프레임을 위한 프레임과 코너점 이월
        prevImg = nextImg
        prevPt = nextMv.reshape(-1,1,2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-cccdd2149a90> in <module>
#      37             nx,ny = n.ravel()
#      38             # 이전 코너와 새로운 코너에 선그리기 ---④
# ---> 39             cv2.line(lines, (px, py), (nx,ny), color[i].tolist(), 2)
#      40             # 새로운 코너에 점 그리기
#      41             cv2.circle(img_draw, (nx,ny), 2, color[i].tolist(), -1)
#
# error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function 'line'
# > Overload resolution failed:
# >  - Can't parse 'pt1'. Sequence item with index 0 has a wrong type
# >  - Can't parse 'pt1'. Sequence item with index 0 has a wrong type

# %%
img = cv2.imread('/content/drive/MyDrive/pose_estimation/data/split_frame/0_0150.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# blob 검출 필터 파라미터 생성 ---①
params = cv2.SimpleBlobDetector_Params()

# 경계값 조정 ---②
params.minThreshold = 10
params.maxThreshold = 240
params.thresholdStep = 5
# 면적 필터 켜고 최소 값 지정 ---③
params.filterByArea = True
params.minArea = 200
  
# 컬러, 볼록 비율, 원형비율 필터 옵션 끄기 ---④
params.filterByColor = False
params.filterByConvexity = False
params.filterByInertia = False
params.filterByCircularity = False 

# 필터 파라미터로 blob 검출기 생성 ---⑤
detector = cv2.SimpleBlobDetector_create(params)
# 키 포인트 검출 ---⑥
keypoints = detector.detect(gray)
# 키 포인트 그리기 ---⑦
img_draw = cv2.drawKeypoints(img, keypoints, None, None,\
                     cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
# 결과 출력 ---⑧
plt.figure(figsize=(20,10))
plt.imshow(img_draw)
plt.show()

# %%
# 특징점 매칭 결과 영상 생성
dst = cv2.drawMatches(src1, kp1, src2, kp2, good_matches, None)
plt.figure(figsize=(20,10))
plt.imshow(dst)
plt.show()
